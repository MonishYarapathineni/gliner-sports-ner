# %% [markdown]
# # 02 — Annotation Review
#
# Inspect GPT-4o-mini annotations and validate annotation quality.

# %%
import json
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

from src.data_pipeline.validator import AnnotationValidator

# %% [markdown]
# ## Load Processed Annotations

# %%
validator = AnnotationValidator()

# TODO: Call validator.load_annotations() and inspect sample records.
# TODO: Print total example count and total entity span count.

# %% [markdown]
# ## Entity Type Distribution

# %%
# TODO: Count spans per entity type and plot bar chart.
# TODO: Flag severely underrepresented types.

# %% [markdown]
# ## Validation Report

# %%
# TODO: Call validator.generate_report() and display summary stats.
# TODO: Call validator.flag_low_quality() and inspect flagged examples.

# %% [markdown]
# ## Manual Spot-Check

# %%
# TODO: Render 10 random examples with entity spans highlighted inline.
# TODO: Use IPython.display HTML for colour-coded span visualization.
