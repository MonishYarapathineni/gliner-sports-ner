# %% [markdown]
# # 03 — Benchmark Analysis
#
# Compare base GLiNER, fine-tuned GLiNER, and GPT-4o-mini on the test set.

# %%
import json
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from src.evaluation.benchmark import NERBenchmark
from src.evaluation.analysis import ErrorAnalyzer, ErrorType

# %% [markdown]
# ## Run Benchmark

# %%
# TODO: Instantiate NERBenchmark and call .run().
# TODO: Display the results DataFrame.

# %% [markdown]
# ## F1 by Entity Type

# %%
# TODO: Compute per-entity-type F1 for each system.
# TODO: Plot grouped bar chart with one group per entity type.

# %% [markdown]
# ## Latency vs. Accuracy Trade-off

# %%
# TODO: Scatter plot: x=p99 latency, y=macro F1, annotate by system name.

# %% [markdown]
# ## Error Analysis

# %%
# TODO: Instantiate ErrorAnalyzer and call categorize_errors for fine-tuned GLiNER.
# TODO: Display error_distribution_by_type heatmap.
# TODO: Print top_failure_examples for MISSED_ENTITY and LABEL_ERROR.

# %% [markdown]
# ## Cost Analysis

# %%
# TODO: Compare GPT cost_per_1k_documents against GLiNER (GPU amortized cost estimate).
# TODO: Table: system × cost × F1 for business decision framing.
